# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By


driver_path = "D:\\chromedriver-win64\\chromedriver-win64\\chromedriver.exe"

service = Service(driver_path)
driver = webdriver.Chrome(service=service)
driver.get("https://www.python.org/")

# %%
elem = driver.find_element(By.ID, "submit")
elems = driver.find_elements(By.ID, "sumbit")
print(elem)
print(elems)
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="99a5ed07ae44378b6ff18eba830920c3", element="f.2BC8C327A0C26CB3BC832A2E85AE52EA.d.0819781106461ECFB46B7B87D7962E87.e.7")>
# []

# %%
elem1 = driver.find_element(By.CLASS_NAME, "widget-title")
elems2 = driver.find_elements(By.CLASS_NAME, "widget-title")
print(elem1)
print(elems2)
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="99a5ed07ae44378b6ff18eba830920c3", element="f.2BC8C327A0C26CB3BC832A2E85AE52EA.d.0819781106461ECFB46B7B87D7962E87.e.35")>
# ...

# %%
elem1 = driver.find_element(By.XPATH, '//*[@id="touchnav-wrapper"]/header/div/div[1]/a')
print(elem1)
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="99a5ed07ae44378b6ff18eba830920c3", element="f.2BC8C327A0C26CB3BC832A2E85AE52EA.d.0819781106461ECFB46B7B87D7962E87.e.46")>

# %%
elem1 = driver.find_element(By.LINK_TEXT, 'Donate')
print(elem1)
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="99a5ed07ae44378b6ff18eba830920c3", element="f.2BC8C327A0C26CB3BC832A2E85AE52EA.d.0819781106461ECFB46B7B87D7962E87.e.46")>

# %%
elem1 = driver.find_element(By.TAG_NAME, 'div')
print(elem1)
elem2 = driver.find_elements(By.TAG_NAME, 'div')
print(elem2)
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="99a5ed07ae44378b6ff18eba830920c3", element="f.2BC8C327A0C26CB3BC832A2E85AE52EA.d.0819781106461ECFB46B7B87D7962E87.e.48")>
# ...

# %%
elem1 = driver.find_element(By.NAME, 'q')
print(elem1)
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="99a5ed07ae44378b6ff18eba830920c3", element="f.2BC8C327A0C26CB3BC832A2E85AE52EA.d.0819781106461ECFB46B7B87D7962E87.e.6")>

# %%
# now performing action chains
