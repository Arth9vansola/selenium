# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import time

# %%
# options = Options()
# options.add_experimental_option("detach", True)
# driver = webdriver.Chrome(options=options)
# driver.get("https://www.python.org/")
# time.sleep(5)
# driver.quit()

# %%
# driver = webdriver.Chrome()
# driver.get('https://www.arthvansola.tech')
# driver.maximize_window()
# time.sleep(5)
# driver.quit()

# %%
# login feature
driver = webdriver.Chrome()
username = "standard_user"
password = "secret_sauce"
login_url = "https://www.saucedemo.com/v1/"
driver.get(login_url)
driver.fullscreen_window()

username_field = driver.find_element(By.ID, 'user-name')
password_field = driver.find_element(By.ID, 'password')
login = driver.find_element(By.ID, "login-button")


username_field.send_keys(username)
password_field.send_keys(password)
assert not login.get_attribute('disabled')
login.click()

success_element = driver.find_element(By.CSS_SELECTOR, '.product_label')
assert success_element.text == 'Products'

driver.back()
time.sleep(5)
driver.refresh()
time.sleep(3)
driver.quit()
# Out:
# ---------------------------------------------------------------------------
# InvalidSessionIdException                 Traceback (most recent call last)
# Cell In[4], line 24
#      22 driver.back()
#      23 time.sleep(5)
# ---> 24 driver.refresh()
#      25 time.sleep(3)
#      26 driver.quit()
#
# File c:\Users\arthv\AppData\Local\Programs\Python\Python312\Lib\site-packages\selenium\webdriver\remote\webdriver.py:728, in WebDriver.refresh(self)
#     721 def refresh(self) -> None:
#     722     """Refreshes the current page.
#     723
#     724     Example:
#     725     --------
#     726     >>> driver.refresh()
#     727     """
# --> 728     self.execute(Command.REFRESH)
#
# File c:\Users\arthv\AppData\Local\Programs\Python\Python312\Lib\site-packages\selenium\webdriver\remote\webdriver.py:458, in WebDriver.execute(self, driver_command, params)
#     455 response = cast(RemoteConnection, self.command_executor).execute(driver_command, params)
#     457 if response:
# ...

# %%
driver = webdriver.Chrome()
login_url = "https://www.saucedemo.com/v1/"
driver.get(login_url)
window_size = [(500,1002),(1002,500),(900,800)]
for i,j in window_size:
  driver.set_window_size(i,j)
  time.sleep(2)
driver.quit()
